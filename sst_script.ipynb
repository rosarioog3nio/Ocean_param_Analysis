# %% [markdown]
# # SST Plotting

# %%
import pandas as pd
#import matplotlib as pyplot
import matplotlib.pyplot as plt

# %%
df_atlantico = pd.read_fwf('sst_atlantico.txt', header = None, names = ['Tempo', 'non','111','444', 'SST'])
df_indico = pd.read_fwf('sst_indico.txt', header = None, names = ['Tempo', 'non', '111','444', 'SST'])
df_pacifico = pd.read_fwf('sst_passifico.txt', header = None, names = ['Tempo', 'non','111','444', 'SST'])

# %%
#del df_atlantico['non','111','444']
#del df_indico['non','111','444']
#del df_passifico['non','111','444']

# %%
type(df_indico)
# Out:
# pandas.core.frame.DataFrame

# %%
df_atlantico['Tempo'] = df_atlantico['Tempo'].astype('datetime64')
df_indico['Tempo'] = df_indico['Tempo'].astype('datetime64')
df_pacifico['Tempo'] = df_indico['Tempo'].astype('datetime64')
#df_pacifico['Tempo'].fillna(df_indico['Tempo'], inplace=True)
df_atlantico = df_atlantico.set_index('Tempo')
df_indico = df_indico.set_index('Tempo')
df_pacifico = df_pacifico.set_index('Tempo')

# %%
#df_pacifico.select_dtypes(['datetime'])
#df_pacifico['Tempo'].fillna(df_pacifico['Tempo'], inplace=True)



df_pacifico.isnull()
# Out:
#               non    111    444    SST
# Tempo
# 2010-05-01  False  False  False  False
# 2010-06-01  False  False  False  False
# 2010-07-01  False  False  False  False
# 2010-08-01  False  False  False  False
# 2010-09-01  False  False  False  False
# ...           ...    ...    ...    ...
# 2020-01-01  False  False  False  False
# 2020-02-01  False  False  False  False
# 2020-03-01  False  False  False  False
# 2020-04-01  False  False  False  False
# 2020-05-01  False  False  False  False
#
# [121 rows x 4 columns]

# %%
df_atlantico.max()
# Out:
# non         0
# 111         /
# 444       99:
# SST    29.765
# dtype: object

# %%
#df_atlantico.idxmax()

# %%
df_indico.min()
# Out:
# non        0
# 111        /
# 444     100:
# SST    24.97
# dtype: object

# %%
#df_indico.idxmin()

# %%
xx = df_indico['SST']

# %%
#xx = statistic.mean(data1)
df_atlantico.describe()
# Out:
#          non         SST
# count  121.0  121.000000
# mean     0.0   26.628636
# std      0.0    1.425687
# min      0.0   24.015000
# 25%      0.0   25.325000
# 50%      0.0   26.625000
# 75%      0.0   27.730000
# max      0.0   29.765000

# %%
sst_atlantico= df_atlantico['SST']
dates_atlantico = df_atlantico.index
sst_indico= df_indico['SST']
dates_indico = df_indico.index
sst_pacifico= df_pacifico['SST']
dates_pacifico = df_pacifico.index

# %%
plt.plot(dates_sul, sst_sul, 'b', label='SST - Sul')
#plt.plot(dates_centro, sst_centro, 'r', label='SST - Centro')
plt.title('')
plt.ylabel('ylabel')
plt.xlabel('xlabel')
plt.legend()
plt.show()

# %%
plt.plot(dates_centro, sst_centro, 'r', label='SST - Centro')
#total_lengths, sort_times_heap, 'b-', label="Heap
plt.title('')
plt.ylabel('SST (C)')
plt.xlabel('Tempo (Anos)')
plt.legend()
plt.show()

# %%
plt.plot(dates_norte, sst_norte, 'g', label='SST - Sul')
#plt.plot(dates_centro, sst_centro, 'r', label='SST - Centro')
plt.title('')
plt.ylabel('ylabel')
plt.xlabel('xlabel')
plt.legend()
plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, sharex=True, sharey=True, figsize=(10, 5))

ax1.set_axisbelow(True)
# Turn on the minor TICKS, which are required for the minor GRID
ax1.minorticks_on()


ax1.grid(which='major', linestyle='-', linewidth='0.5')
ax2.grid(which='major', linestyle='-', linewidth='0.5')
ax3.grid(which='major', linestyle='-', linewidth='0.5')

# Customize the minor grid
ax1.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax2.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax3.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
fig.suptitle('Variacao do SST')
ax1.plot(dates_atlantico,sst_atlantico)
ax2.plot(dates_indico, sst_indico)
ax3.plot(dates_pacifico, sst_pacifico)



ax3.set_xlabel('Tempo (Anos)')
ax2.set_ylabel('Temperatura (°C)')
plt.grid(True)
ax1.set_title('Oceano Atlantico')
ax2.set_title('Oceano Indico')
ax3.set_title('Oceano Pacifico')
plt.grid(True)

# %%
plt. savefig()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-5d5e4bf4512d> in <module>
# ----> 1 plt. savefig()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# TypeError: savefig() missing 1 required positional argument: 'fname'
